# %%
# TechKava

# %%
price = 65.5
amount_of_coffee = int(input("Enter the quantity of the product: "))
order_cost = amount_of_coffee*price
print(f" Total cost of the order is: {order_cost} UAH")

# or
# print(f" Total cost of the order is: {amount_of_coffee*price} UAH")
# Out:
#  Total cost of the order is: 393.0 UAH

# %%
expenses = float(input("Enter the amount of expenses: "))
revenue = float(input("Enter total revenue: "))
net_profit = revenue - expenses
print(net_profit)
# Out:
# 550000.0

# %%
principal = 10000
r = 15
t = 5
amount = principal*(1+r/100)**t
print(round(amount, 3))

# or
# print(amount:.2f)
# Out:
# 20113.572

# %%
investment_cost = float(input("How much did you invest? : "))
total_revenue = float(input("What is your revenue? : "))
roi = 100*(total_revenue-investment_cost)/investment_cost
print(f"{roi}%")
# Out:
# 81.00005913004317%

# %%
receipt = float(input("Enter the cost of the order: "))
tip_percentage = float(input("How much do you want to tip (enter the value in percentage)?: "))/100
final_price = receipt*(1+tip_percentage)
people = int(input("How many people in the company?: "))
individually = final_price/people

print(f"Your tip percentage: {tip_percentage*100}% \nYour receipt: {final_price} UAH\n Each person need to drop: {individually} UAH")
# Out:
# Your tip percentage: 50.0%
# Your receipt: 1500.0 UAH
#  Each person need to drop: 500.0 UAH

# %% [markdown]
# Here is some problems solved in Eolymp:
# ![image.png](attachment:e99f8ff0-c403-440c-9e07-aa8a0495c561.png)
